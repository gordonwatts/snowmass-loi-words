# %% [markdown]
# # Scatter Plot Visualization Data
#
# Lets Try:
#
# - Put all the LOI's on a single 2D plot
# - Each point represents an LOI document
# - The coordinates of the point are from some sort of clustering
# - The color of the point is the area it was submitted to
# - Mouse over gets you some "intersting" metadata:
#    - The filename
#    - The first 100 characters of text
#    - An active link to the PDF
#
# In order to do this we need to generate a bunch of data and write it out in a CSV file.

# %% [markdown]
# ## Config

# %%
n_components = 2
n_word_summary = 100

# %% [markdown]
# ## Setup

# %%
from config import text_file_info, word_vectors

# from collections import defaultdict
from pathlib import Path
import json

from sklearn.decomposition import PCA

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Files

# %%
file_by_area = list(text_file_info())

# %%
data_filenames = [f[2] for f in file_by_area]
file_names = [f[0] for f in file_by_area]
file_areas = [f[1] for f in file_by_area]

# %% [markdown]
# ## Text
#
# We want the first n words of text from each file. Grab them here.

# %%
file_text_summary = [' '.join(Path(f).read_text().split()[:n_word_summary]) for f in data_filenames]

# %% [markdown]
# ## 2D Coordinates from Text Contents

# %%
# %%time
x, vectorizer = word_vectors(data_filenames)
# Out:
# CPU times: user 2.9 s, sys: 597 ms, total: 3.5 s
# Wall time: 9.21 s

# %% [markdown]
# Now we do the Principle Component Analysis

# %%
pca = PCA(n_components)

# %%
# %%time
loi_coordinates = pca.fit_transform(x.A)
# Out:
# CPU times: user 1.9 s, sys: 2.35 s, total: 4.25 s
# Wall time: 602 ms

# %% [markdown]
# Round them so we don't send too much data.

# %%
loi_coordinates = np.round(loi_coordinates, decimals=4)

# %% [markdown]
# Lets use `seaborn` to make a plot of this.

# %%
document_data = [
    {
        'x': x,
        'y': y,
        'name': str(name),
        'area': str(area),
        'url': f'https://www.snowmass21.org/docs/files/summaries/{area}/{name}.pdf',
        'summary': str(summary),
        'index': index
    }
    for index, ((x, y), name, area, summary) in enumerate(zip(loi_coordinates, file_names, file_areas, file_text_summary))
]
document_df = pd.DataFrame(document_data)

# %%
document_df
# Out:
#            x       y                                               name area  \
# 0    -0.0723  0.0132                           SNOWMASS21-AF-TOPIC0-001   AF
# 1    -0.1064 -0.0384                                 SNOWMASS21-AF0-015   AF
# 2    -0.0293  0.0647                             SNOWMASS21-AF0_AF0-091   AF
# 3    -0.1122 -0.0795                             SNOWMASS21-AF0_AF0-215   AF
# 4    -0.1335 -0.0566                             SNOWMASS21-AF0_AF0-229   AF
# ...      ...     ...                                                ...  ...
# 1509 -0.0053 -0.0047             SNOWMASS21-UF0_UF0_Garcia-Sciveres-001   UF
# 1510  0.0063  0.0686            SNOWMASS21-UF1_UF4-RF4_RF3_ODonnell-007   UF
# 1511  0.1692 -0.0093  SNOWMASS21-UF4_UF3-NF5_NF6-CF1_CF0-IF3_IF0-Com...   UF
# 1512  0.0813  0.0255  SNOWMASS21-UF6_UF0-NF10_NF0-RF4_RF0-CF1_CF0-IF...   UF
# 1513  0.0197  0.0102  SNOWMASS21-UF6_UF4-NF5_NF0-CF1_CF0_Tim_Sumner-003   UF
#
#                                                     url  \
# 0     https://www.snowmass21.org/docs/files/summarie...
# 1     https://www.snowmass21.org/docs/files/summarie...
# 2     https://www.snowmass21.org/docs/files/summarie...
# 3     https://www.snowmass21.org/docs/files/summarie...
# 4     https://www.snowmass21.org/docs/files/summarie...
# ...                                                 ...
# 1509  https://www.snowmass21.org/docs/files/summarie...
# 1510  https://www.snowmass21.org/docs/files/summarie...
# 1511  https://www.snowmass21.org/docs/files/summarie...
# 1512  https://www.snowmass21.org/docs/files/summarie...
# 1513  https://www.snowmass21.org/docs/files/summarie...
#
#                                                 summary  index
# 0     May 21, 2020 Gamma Factory L ETTER OF I NTERES...      0
# 1     July 30th ,2020 2020 snowmass Letter of Intere...      1
# 2     POTENTIAL FOR HIGH-ENERGY PHYSICS AT THE OAK R...      2
# 3     Plasma Processing for In-Situ Field Emission M...      3
# 4     Letter of Interest for Snowmass2021: R&D on Hi...      4
# ...                                                 ...    ...
# 1509  Snowmass2021 Letter of Interest: Classificatio...   1509
# 1510  KURF: The Kimballton Underground Research Faci...   1510
# 1511  Snowmass2021 - Letter of Interest Advanced Ger...   1511
# 1512  Snowmass2021 - Letter of Interest Solution-min...   1512
# 1513  Snowmass2021 Letter of Interest: Development o...   1513
#
# [1514 rows x 7 columns]

# %%
plt.figure(figsize=(15,15))
g = sns.scatterplot(x='x', y='y', hue=document_df.area.to_list(), data=document_df)

# %% [markdown]
# ## Writing out the data

# %%
document_df.to_csv('../web/data/loi-data.csv')

# %% [markdown]
# ## Word Frequency and Importance Data
#
# Generate the JSON file for word importance. This allows one to identify which documents use which words, and what their relative importance is.

# %%
terms = vectorizer.get_feature_names()

# %%
# %%time
term_usage_info = {}
for t_index, t in enumerate(terms):
    non_zero_index = np.nonzero(x[:,t_index])[0]
    non_zero_weight = np.take(x[:,t_index].toarray(), non_zero_index)
    non_zero_weight = np.round(non_zero_weight, decimals=4)
    doc_word_usage = {int(i): wt for i,wt in zip(non_zero_index, non_zero_weight)}
    term_usage_info[t] = doc_word_usage
# Out:
# CPU times: user 25.3 s, sys: 0 ns, total: 25.3 s
# Wall time: 25.3 s

# %%
len(term_usage_info['mathusla'])
# Out:
# 19

# %%
with open('../web/data/term_data.json', 'wt') as fout:
    json.dump(term_usage_info, fout)
